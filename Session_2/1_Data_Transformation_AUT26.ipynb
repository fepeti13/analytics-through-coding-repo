# %% [markdown]
# # Session 2.1 : Data Transformation
#
# _Analytics Through Coding Autumn 2026_
#
# ---
#
# Visualisation and statistical analysis are only useful if the data are in the form required to answer the question.
#
# In practice, we often need to:
#
# * keep only relevant observations;
# * reorder observations;
# * select or rename variables;
# * create new variables;
# * group observations;
# * calculate summaries.
#
# In this session we will use the `flights` dataset, which contains flights that departed from New York City in 2013.
#
# Rather than learning pandas functions in isolation, we will start with an **analytical question** and then decide what transformation is needed.
#
# ---

# %% [markdown]
# ## Starting out
#
# As always, import the necessary libraries and dataset at the start of the notebook.

# %%
import pandas as pd
import numpy as np

flights = pd.read_csv("../Data/nycflights13_flights.csv", index_col=0)
flights.reset_index(drop=True, inplace=True)

flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      3   25    1929.0            1905       24.0    2236.0
# 1  2013      4   26     956.0            1000       -4.0    1257.0
# 2  2013      5   21    1320.0            1309       11.0    1430.0
# 3  2013      7   18    1222.0            1230       -8.0    1357.0
# 4  2013      8   29     540.0             545       -5.0     921.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0            2217       19.0      UA    1471  N37298    EWR  RSW     169.0
# 1            1334      -37.0      DL    1765  N717TW    JFK  SFO     337.0
# 2            1414       16.0      EV    4129  N11536    EWR  DCA      39.0
# 3            1419      -22.0      EV    5796  N13958    EWR  CLT      77.0
# 4             921        0.0      B6     939  N535JB    JFK  BQN     198.0
#
#    distance  hour  minute            time_hour
# 0      1068    19       5  2013-03-25 19:00:00
# 1      2586    10       0  2013-04-26 10:00:00
# 2       199    13       9  2013-05-21 13:00:00
# 3       529    12      30  2013-07-18 12:00:00
# 4      1576     5      45  2013-08-29 05:00:00

# %% [markdown]
# Before transforming a dataset, remind yourself what one row represents and check the variables available.

# %%
print("Shape:", flights.shape)
print(flights.columns.tolist())
# Out:
# Shape: (202066, 19)
# ['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay', 'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight', 'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute', 'time_hour']

# %% [markdown]
# ## A small set of transformation tools
#
# We will focus on a small number of pandas methods that can be combined to answer many analytical questions.
#
# | pandas method | What it helps us do |
# |---|---|
# | `query()` | Keep observations that satisfy a condition |
# | `sort_values()` | Reorder observations |
# | `loc[]` | Select rows and/or columns |
# | `rename()` | Rename variables |
# | `assign()` | Create new variables |
# | `groupby()` | Divide observations into groups |
# | `agg()` | Calculate summaries |
#
# The important skill is not memorising this table. It is recognising **which operation is required by the analytical question**.

# %% [markdown]
# ## Question 1: Which flights departed on 16 August?
#
# We only want observations where:
#
# * `month == 8`
# * `day == 16`
#
# We can use `.query()` to filter observations.

# %%
flights.query("month == 8 and day == 16")
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 286     2013      8   16    1510.0            1455       15.0    1652.0
# 410     2013      8   16    1256.0            1255        1.0    1543.0
# 707     2013      8   16    1959.0            2000       -1.0    2242.0
# 1564    2013      8   16     619.0             620       -1.0     906.0
# 1573    2013      8   16    2156.0            2159       -3.0    2258.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 201628  2013      8   16    1706.0            1700        6.0    1839.0
# 201779  2013      8   16     635.0             640       -5.0    1020.0
# 201929  2013      8   16    1700.0            1659        1.0    1835.0
# 202047  2013      8   16    1758.0            1759       -1.0    2046.0
# 202048  2013      8   16    1738.0            1745       -7.0    1917.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 286               1701       -9.0      9E    4120  N8775A    JFK  CLE
# 410               1545       -2.0      UA    1641  N19136    EWR  MCO
# 707               2310      -28.0      DL    2391  N916DL    JFK  TPA
# 1564               843       23.0      DL    1743  N6704Z    JFK  ATL
# 1573              2324      -26.0      UA    1116  N71411    EWR  BOS
# ...                ...        ...     ...     ...     ...    ...  ...
# 201628            1846       -7.0      UA    1281  N13750    LGA  ORD
# 201779            1040      -20.0      AA     413  N3HBAA    JFK  SJU
# 201929            1839       -4.0      EV    4202  N13979    EWR  STL
# 202047            2106      -20.0      DL    1585  N991DL    LGA  MCO
# 202048            1925       -8.0      MQ    3301  N510MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour
# 286         73.0       425    14      55  2013-08-16 14:00:00
# 410        143.0       937    12      55  2013-08-16 12:00:00
# 707        146.0      1005    20       0  2013-08-16 20:00:00
# 1564       121.0       760     6      20  2013-08-16 06:00:00
# 1573        42.0       200    21      59  2013-08-16 21:00:00
# ...          ...       ...   ...     ...                  ...
# 201628     116.0       733    17       0  2013-08-16 17:00:00
# 201779     203.0      1598     6      40  2013-08-16 06:00:00
# 201929     127.0       872    16      59  2013-08-16 16:00:00
# 202047     145.0       950    17      59  2013-08-16 17:00:00
# 202048      76.0       431    17      45  2013-08-16 17:00:00
#
# [608 rows x 19 columns]

# %% [markdown]
# Notice that pandas returns a **new DataFrame**. The original `flights` DataFrame has not been changed.

# %% [markdown]
# Multiple arguments to `.query()` are combined with `“and”`: every expression must be true in order for a row to be included in the output. For some operations you may need other Boolean operations - `&` is “and”, `|` is “or”, and `!` is “not”
#
# ![GitHub Codespaces](Boolean_operators.png)

# %% [markdown]
# ### Exercise 1
#
# Find all flights that:
#
# * departed from `JFK`;
# * travelled to `LAX`; and
# * had a departure delay greater than 60 minutes.
#
# Keep the result in a DataFrame called `jfk_lax_delayed`.
#
# How many flights meet all three conditions?

# %%
jfk_lax_delayed = flights.query(
    "origin == 'JFK' and dest == 'LAX' and dep_delay > 60"
)

display(jfk_lax_delayed)
print(len(jfk_lax_delayed))
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 689     2013      8    5    2206.0            1915      171.0      38.0
# 832     2013      1   31    1011.0             900       71.0    1320.0
# 1782    2013      6    1    1439.0            1300       99.0    1741.0
# 2284    2013      5   17    1701.0            1545       76.0    1944.0
# 2751    2013      6   28    2259.0            2150       69.0     143.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 199460  2013      8   18    1932.0            1300      392.0    2239.0
# 199500  2013      2   10    1113.0             905      128.0    1428.0
# 199644  2013      9   11    2228.0            2000      148.0     102.0
# 201534  2013      6   25    2227.0            2025      122.0     201.0
# 201888  2013      7   10    2146.0            2001      105.0     136.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 689               2230      128.0      AA      21  N327AA    JFK  LAX
# 832               1227       53.0      DL     120  N624AG    JFK  LAX
# 1782              1555      106.0      VX     411  N627VA    JFK  LAX
# 2284              1910       34.0      AA     133  N338AA    JFK  LAX
# 2751               100       43.0      AA     185  N335AA    JFK  LAX
# ...                ...        ...     ...     ...     ...    ...  ...
# 199460            1555      404.0      VX     411  N631VA    JFK  LAX
# 199500            1235      113.0      VX     407  N638VA    JFK  LAX
# 199644            2300      122.0      VX     415  N642VA    JFK  LAX
# 201534            2324      157.0      UA     771  N557UA    JFK  LAX
# 201888            2305      151.0      VX     415  N633VA    JFK  LAX
#
#         air_time  distance  hour  minute            time_hour
# 689        302.0      2475    19      15  2013-08-05 19:00:00
# 832        338.0      2475     9       0  2013-01-31 09:00:00
# 1782       334.0      2475    13       0  2013-06-01 13:00:00
# 2284       316.0      2475    15      45  2013-05-17 15:00:00
# 2751       320.0      2475    21      50  2013-06-28 21:00:00
# ...          ...       ...   ...     ...                  ...
# 199460     313.0      2475    13       0  2013-08-18 13:00:00
# 199500     352.0      2475     9       5  2013-02-10 09:00:00
# 199644     310.0      2475    20       0  2013-09-11 20:00:00
# 201534     343.0      2475    20      25  2013-06-25 20:00:00
# 201888     355.0      2475    20       1  2013-07-10 20:00:00
#
# [359 rows x 19 columns]
# 359

# %% [markdown]
# ## Question 2: Which flights experienced the largest departure delays?
#
# Filtering determines **which observations we keep**.
#
# Sorting determines **the order in which we inspect them**.

# %%
flights.sort_values('dep_delay', ascending=False)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 114519  2013      1    9     641.0             900     1301.0    1242.0
# 74463   2013      1   10    1121.0            1635     1126.0    1239.0
# 176637  2013      9   20    1139.0            1845     1014.0    1457.0
# 201196  2013      3   17    2321.0             810      911.0     135.0
# 53590   2013      7   22    2257.0             759      898.0     121.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 201790  2013      2    8       NaN            1720        NaN       NaN
# 201852  2013      4   19       NaN            1755        NaN       NaN
# 201856  2013      1   17       NaN            1722        NaN       NaN
# 201942  2013      1   26       NaN            1240        NaN       NaN
# 201957  2013      9   12       NaN            1625        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 114519            1530     1272.0      HA      51  N384HA    JFK  HNL
# 74463             1810     1109.0      MQ    3695  N517MQ    EWR  ORD
# 176637            2210     1007.0      AA     177  N338AA    JFK  SFO
# 201196            1020      915.0      DL    2119  N927DA    LGA  MSP
# 53590             1026      895.0      DL    2047  N6716C    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 201790            1905        NaN      MQ    4479  N737MQ    LGA  RDU
# 201852            1930        NaN      MQ    4601  N504MQ    LGA  RDU
# 201856            1844        NaN      EV    4300  N16911    EWR  RIC
# 201942            1540        NaN      AA    1853  N434AA    EWR  DFW
# 201957            1743        NaN      EV    4473  N13994    EWR  ROC
#
#         air_time  distance  hour  minute            time_hour
# 114519     640.0      4983     9       0  2013-01-09 09:00:00
# 74463      111.0       719    16      35  2013-01-10 16:00:00
# 176637     354.0      2586    18      45  2013-09-20 18:00:00
# 201196     167.0      1020     8      10  2013-03-17 08:00:00
# 53590      109.0       762     7      59  2013-07-22 07:00:00
# ...          ...       ...   ...     ...                  ...
# 201790       NaN       431    17      20  2013-02-08 17:00:00
# 201852       NaN       431    17      55  2013-04-19 17:00:00
# 201856       NaN       277    17      22  2013-01-17 17:00:00
# 201942       NaN      1372    12      40  2013-01-26 12:00:00
# 201957       NaN       246    16      25  2013-09-12 16:00:00
#
# [202066 rows x 19 columns]

# %% [markdown]
# We can also sort using more than one variable.
#
# For example, the following sorts chronologically by month and day.

# %%
flights.sort_values(['month', 'day'])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 241     2013      1    1    1451.0            1500       -9.0    1634.0
# 897     2013      1    1    2050.0            1959       51.0    2229.0
# 926     2013      1    1     800.0             810      -10.0     949.0
# 1399    2013      1    1    1628.0            1524       64.0    1740.0
# 1960    2013      1    1    1825.0            1829       -4.0    2046.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 199757  2013     12   31     622.0             630       -8.0     945.0
# 200522  2013     12   31    1912.0            1915       -3.0    2300.0
# 201122  2013     12   31    1352.0            1350        2.0    1707.0
# 201615  2013     12   31    1429.0            1429        0.0    1745.0
# 201774  2013     12   31     905.0             856        9.0    1231.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 241               1636       -2.0      9E    4105  N8444F    JFK  IAD
# 897               2144       45.0      MQ    4423  N853MQ    JFK  RDU
# 926                955       -6.0      MQ    4406  N828MQ    JFK  RDU
# 1399              1641       59.0      EV    4133  N14959    EWR  IAD
# 1960              2032       14.0      US    1973  N460UW    EWR  CLT
# ...                ...        ...     ...     ...     ...    ...  ...
# 199757             938        7.0      B6     929  N612JB    JFK  RSW
# 200522            2258        2.0      DL    2481  N385DN    JFK  PHX
# 201122            1705        2.0      AA    1073  N3JEAA    LGA  MIA
# 201615            1737        8.0      B6     301  N715JB    JFK  FLL
# 201774            1206       25.0      UA     205  N418UA    EWR  FLL
#
#         air_time  distance  hour  minute            time_hour
# 241         57.0       228    15       0  2013-01-01 15:00:00
# 897         83.0       427    19      59  2013-01-01 19:00:00
# 926         80.0       427     8      10  2013-01-01 08:00:00
# 1399        53.0       212    15      24  2013-01-01 15:00:00
# 1960       106.0       529    18      29  2013-01-01 18:00:00
# ...          ...       ...   ...     ...                  ...
# 199757     185.0      1074     6      30  2013-12-31 06:00:00
# 200522     320.0      2153    19      15  2013-12-31 19:00:00
# 201122     169.0      1096    13      50  2013-12-31 13:00:00
# 201615     172.0      1069    14      29  2013-12-31 14:00:00
# 201774     181.0      1065     8      56  2013-12-31 08:00:00
#
# [202066 rows x 19 columns]

# %% [markdown]
# ### Exercise 2
#
# Find the **10 flights with the longest arrival delays**.
#
# Display only:
#
# * `origin`
# * `dest`
# * `carrier`
# * `arr_delay`
#
# Sort the result from the largest delay to the smallest.

# %%
largest_arr_delay = flights[['origin', 'dest', 'carrier', 'arr_delay']].sort_values('arr_delay', ascending=False).head(10)
largest_arr_delay
# Out:
#        origin dest carrier  arr_delay
# 114519    JFK  HNL      HA     1272.0
# 74463     EWR  ORD      MQ     1109.0
# 176637    JFK  SFO      AA     1007.0
# 201196    LGA  MSP      DL      915.0
# 53590     LGA  ATL      DL      895.0
# 150167    EWR  ORD      MQ      875.0
# 194528    JFK  TPA      DL      856.0
# 54279     JFK  LAS      AA      852.0
# 103118    JFK  BWI      MQ      851.0
# 151237    EWR  SLC      DL      847.0

# %% [markdown]
# ## Question 3: Which variables do we actually need?
#
# Real datasets often contain many more variables than are required for a particular question.
#
# For an analysis of flight delays, we might only need a subset of columns.

# %% [markdown]
# We can also rename variables when a clearer name would make later code easier to read.

# %%
flights.rename(
    columns={
        'dep_time': 'departure_time',
        'arr_time': 'arrival_time'
    }
).head()
# Out:
#    year  month  day  departure_time  sched_dep_time  dep_delay  arrival_time  \
# 0  2013      3   25          1929.0            1905       24.0        2236.0
# 1  2013      4   26           956.0            1000       -4.0        1257.0
# 2  2013      5   21          1320.0            1309       11.0        1430.0
# 3  2013      7   18          1222.0            1230       -8.0        1357.0
# 4  2013      8   29           540.0             545       -5.0         921.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0            2217       19.0      UA    1471  N37298    EWR  RSW     169.0
# 1            1334      -37.0      DL    1765  N717TW    JFK  SFO     337.0
# 2            1414       16.0      EV    4129  N11536    EWR  DCA      39.0
# 3            1419      -22.0      EV    5796  N13958    EWR  CLT      77.0
# 4             921        0.0      B6     939  N535JB    JFK  BQN     198.0
#
#    distance  hour  minute            time_hour
# 0      1068    19       5  2013-03-25 19:00:00
# 1      2586    10       0  2013-04-26 10:00:00
# 2       199    13       9  2013-05-21 13:00:00
# 3       529    12      30  2013-07-18 12:00:00
# 4      1576     5      45  2013-08-29 05:00:00

# %% [markdown]
# <div class="alert alert-warning">
# <b>Note.</b>
# Selecting or renaming columns does not improve the analysis by itself. Do it when it makes the dataset easier to understand or when only a smaller set of variables is needed for the question.
# </div>

# %% [markdown]
# ## Question 4: Did flights make up time while in the air?
#
# Sometimes the variable we need does not exist in the original dataset.
#
# We can create a new variable from existing variables using `.assign()`.
#
# Define:
#
# `gain = arrival delay - departure delay`
#
# A negative value means the flight arrived with **less delay** than it had when it departed.

# %%
flights.assign(
    gain=flights['arr_delay'] - flights['dep_delay']
)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      3   25    1929.0            1905       24.0    2236.0
# 1       2013      4   26     956.0            1000       -4.0    1257.0
# 2       2013      5   21    1320.0            1309       11.0    1430.0
# 3       2013      7   18    1222.0            1230       -8.0    1357.0
# 4       2013      8   29     540.0             545       -5.0     921.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 202061  2013      1   27    1311.0            1315       -4.0    1451.0
# 202062  2013      8    8    2145.0            1800      225.0       8.0
# 202063  2013      1   30    2248.0            2135       73.0     149.0
# 202064  2013      3   18     957.0            1000       -3.0    1242.0
# 202065  2013      9    6     600.0             610      -10.0     825.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                 2217       19.0      UA    1471  N37298    EWR  RSW
# 1                 1334      -37.0      DL    1765  N717TW    JFK  SFO
# 2                 1414       16.0      EV    4129  N11536    EWR  DCA
# 3                 1419      -22.0      EV    5796  N13958    EWR  CLT
# 4                  921        0.0      B6     939  N535JB    JFK  BQN
# ...                ...        ...     ...     ...     ...    ...  ...
# 202061            1504      -13.0      US    1895  N192UW    EWR  CLT
# 202062            2039      209.0      DL      61  N685DA    LGA  ATL
# 202063              36       73.0      B6      11  N809JB    JFK  FLL
# 202064            1234        8.0      DL    1847  N397DA    LGA  ATL
# 202065             855      -30.0      AA    1103  N3FDAA    LGA  DFW
#
#         air_time  distance  hour  minute            time_hour  gain
# 0          169.0      1068    19       5  2013-03-25 19:00:00  -5.0
# 1          337.0      2586    10       0  2013-04-26 10:00:00 -33.0
# 2           39.0       199    13       9  2013-05-21 13:00:00   5.0
# 3           77.0       529    12      30  2013-07-18 12:00:00 -14.0
# 4          198.0      1576     5      45  2013-08-29 05:00:00   5.0
# ...          ...       ...   ...     ...                  ...   ...
# 202061      77.0       529    13      15  2013-01-27 13:00:00  -9.0
# 202062     104.0       762    18       0  2013-08-08 18:00:00 -16.0
# 202063     166.0      1069    21      35  2013-01-30 21:00:00   0.0
# 202064     112.0       762    10       0  2013-03-18 10:00:00  11.0
# 202065     177.0      1389     6      10  2013-09-06 06:00:00 -20.0
#
# [202066 rows x 20 columns]

# %% [markdown]
# We can create several new variables at the same time.
#
# For example, approximate average speed in miles per hour can be calculated from `distance` and `air_time`.

# %%
flights.assign(
    avg_speed=flights['distance'] / flights['air_time'] * 60
)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      3   25    1929.0            1905       24.0    2236.0
# 1       2013      4   26     956.0            1000       -4.0    1257.0
# 2       2013      5   21    1320.0            1309       11.0    1430.0
# 3       2013      7   18    1222.0            1230       -8.0    1357.0
# 4       2013      8   29     540.0             545       -5.0     921.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 202061  2013      1   27    1311.0            1315       -4.0    1451.0
# 202062  2013      8    8    2145.0            1800      225.0       8.0
# 202063  2013      1   30    2248.0            2135       73.0     149.0
# 202064  2013      3   18     957.0            1000       -3.0    1242.0
# 202065  2013      9    6     600.0             610      -10.0     825.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                 2217       19.0      UA    1471  N37298    EWR  RSW
# 1                 1334      -37.0      DL    1765  N717TW    JFK  SFO
# 2                 1414       16.0      EV    4129  N11536    EWR  DCA
# 3                 1419      -22.0      EV    5796  N13958    EWR  CLT
# 4                  921        0.0      B6     939  N535JB    JFK  BQN
# ...                ...        ...     ...     ...     ...    ...  ...
# 202061            1504      -13.0      US    1895  N192UW    EWR  CLT
# 202062            2039      209.0      DL      61  N685DA    LGA  ATL
# 202063              36       73.0      B6      11  N809JB    JFK  FLL
# 202064            1234        8.0      DL    1847  N397DA    LGA  ATL
# 202065             855      -30.0      AA    1103  N3FDAA    LGA  DFW
#
#         air_time  distance  hour  minute            time_hour  avg_speed
# 0          169.0      1068    19       5  2013-03-25 19:00:00   6.319527
# 1          337.0      2586    10       0  2013-04-26 10:00:00   7.673591
# 2           39.0       199    13       9  2013-05-21 13:00:00   5.102564
# 3           77.0       529    12      30  2013-07-18 12:00:00   6.870130
# 4          198.0      1576     5      45  2013-08-29 05:00:00   7.959596
# ...          ...       ...   ...     ...                  ...        ...
# 202061      77.0       529    13      15  2013-01-27 13:00:00   6.870130
# 202062     104.0       762    18       0  2013-08-08 18:00:00   7.326923
# 202063     166.0      1069    21      35  2013-01-30 21:00:00   6.439759
# 202064     112.0       762    10       0  2013-03-18 10:00:00   6.803571
# 202065     177.0      1389     6      10  2013-09-06 06:00:00   7.847458
#
# [202066 rows x 20 columns]

# %% [markdown]
# ### Exercise 3
#
# Create a DataFrame called `flights_delay_change` containing a new variable:
#
# `delay_change = arr_delay - dep_delay`
#
# Then keep only flights where `delay_change <= -30`.
#
# These are flights that reduced their delay by at least 30 minutes between departure and arrival.
#
# Display the 10 flights with the largest reduction in delay.

# %%
flights_delay_change = flights.assign(
    delay_change=flights['arr_delay'] - flights['dep_delay']
)

flights_delay_change[flights_delay_change['delay_change'] <= -30].sort_values('delay_change').head(10)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 62257   2013      6   13    1907.0            1512      235.0    2134.0
# 10546   2013      2   26    1000.0             900       60.0    1513.0
# 127816  2013      2   23    1226.0             900      206.0    1746.0
# 167806  2013      5   13    1917.0            1900       17.0    2149.0
# 102639  2013      2   27     924.0             900       24.0    1448.0
# 5530    2013      7   14    1917.0            1829       48.0    2109.0
# 55943   2013      5    2    1947.0            1949       -2.0    2209.0
# 108369  2013     11   13    2024.0            2015        9.0    2251.0
# 9831    2013      5    2    1949.0            1910       39.0    2208.0
# 15531   2013      5    4    1816.0            1820       -4.0    2017.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 62257             1928      126.0      EV    4377  N19554    EWR  JAX
# 10546             1540      -27.0      HA      51  N382HA    JFK  HNL
# 127816            1540      126.0      HA      51  N389HA    JFK  HNL
# 167806            2251      -62.0      DL    1465  N721TW    JFK  SFO
# 102639            1540      -52.0      HA      51  N389HA    JFK  HNL
# 5530              2135      -26.0      UA     673  N817UA    EWR  SNA
# 55943             2324      -75.0      UA     612  N851UA    EWR  LAX
# 108369            2354      -63.0      DL     427  N188DN    JFK  LAX
# 9831              2240      -32.0      AA      21  N339AA    JFK  LAX
# 15531             2131      -74.0      AS       7  N551AS    EWR  SEA
#
#         air_time  distance  hour  minute            time_hour  delay_change
# 62257      126.0       820    15      12  2013-06-13 15:00:00        -109.0
# 10546      584.0      4983     9       0  2013-02-26 09:00:00         -87.0
# 127816     599.0      4983     9       0  2013-02-23 09:00:00         -80.0
# 167806     313.0      2586    19       0  2013-05-13 19:00:00         -79.0
# 102639     589.0      4983     9       0  2013-02-27 09:00:00         -76.0
# 5530       274.0      2434    18      29  2013-07-14 18:00:00         -74.0
# 55943      300.0      2454    19      49  2013-05-02 19:00:00         -73.0
# 108369     311.0      2475    20      15  2013-11-13 20:00:00         -72.0
# 9831       301.0      2475    19      10  2013-05-02 19:00:00         -71.0
# 15531      281.0      2402    18      20  2013-05-04 18:00:00         -70.0

# %% [markdown]
# ## Question 5: What is a typical delay?
#
# `.agg()` allows us to collapse many observations into summary statistics.
#
# Without grouping, the summary describes the **entire dataset**.

# %%
flights.agg(
    dep_delay_sum=('dep_delay', 'sum'),
    dep_delay_mean=('dep_delay', 'mean'),
    arr_delay_mean=('arr_delay', 'median')
)
# Out:
#                    dep_delay  arr_delay
# dep_delay_sum   2.489011e+06        NaN
# dep_delay_mean  1.262323e+01        NaN
# arr_delay_mean           NaN       -5.0

# %% [markdown]
# ## Question 6: Does delay differ between airports or airlines?
#
# Usually we want summaries **within groups**.
#
# `groupby()` changes the unit of analysis.
#
# Instead of one row representing one flight, the resulting table can have one row representing one airport, airline, month, destination, or another group.

# %%
flights.groupby(['origin', 'dest']).agg(
    dep_delay_sum=('dep_delay', 'mean'),
    arr_delay_median=('arr_delay', 'median')
).reset_index()
# Out:
#     origin dest  dep_delay_sum  arr_delay_median
# 0      EWR  ALB      21.515901              -5.5
# 1      EWR  ANC      15.600000              10.0
# 2      EWR  ATL      15.058128              -1.0
# 3      EWR  AUS      10.325744              -9.0
# 4      EWR  AVL      10.413333               1.0
# ..     ...  ...            ...               ...
# 216    LGA  SYR      23.664596              -6.0
# 217    LGA  TPA      11.018239              -5.0
# 218    LGA  TVC      26.818182              -7.0
# 219    LGA  TYS      11.025974              -6.0
# 220    LGA  XNA       8.182670              -2.0
#
# [221 rows x 4 columns]

# %% [markdown]
# This is an important conceptual change:
#
# > Before `groupby()`: one row = one flight
# > After `groupby()` + `agg()`: one row = one origin airport
#
# Always know what **one row represents** after a transformation.

# %% [markdown]
# ### Exercise 4
#
# Calculate the following for each airline (`carrier`):
#
# * `n_flights`: number of flights;
# * `avg_dep_delay`: average departure delay;
# * `avg_arr_delay`: average arrival delay.
#
# Keep only airlines with at least 1,000 flights and sort them from the **lowest to highest average arrival delay**.

# %%
big_carriers = (
    flights
    .groupby('carrier')
    .agg(
        n_flights=('flight', 'size'),
        avg_dep_delay=('dep_delay', 'mean'),
        avg_arr_delay=('arr_delay', 'mean')
    )
    .query("n_flights >= 1000")
    .reset_index()
    .sort_values('avg_arr_delay')
)
big_carriers
# Out:
#    carrier  n_flights  avg_dep_delay  avg_arr_delay
# 1       AA      19563       8.406411       0.383085
# 9       VX       3109      12.668714       1.578196
# 3       DL      28774       9.363554       1.848063
# 8       US      12384       3.866450       2.287291
# 7       UA      35205      11.869524       3.323555
# 0       9E      11032      16.512983       7.021901
# 10      WN       7394      17.047298       9.123862
# 2       B6      32910      13.185801       9.764146
# 6       MQ      15806      10.901307      10.991669
# 4       EV      32519      19.976493      15.858449
# 5       FL       1962      18.042144      19.608877

# %% [markdown]
# ## Combining transformations
#
# Real analytical questions usually require more than one operation.
#
# Method chaining lets us read the analysis as a sequence:
#
# 1. start with the data;
# 2. create or modify variables;
# 3. group observations;
# 4. calculate summaries;
# 5. filter the summaries;
# 6. order the result.
#
# This mirrors the analytical workflow more closely than learning each method separately.

# %% [markdown]
# ### Final Exercise — Average speed by destination
#
# Imagine you want to know how fast flights travel on average depending on destination.
#
# Create a new variable:
#
# `speed = distance / (air_time / 60)`
#
# Then, for each destination (`dest`), calculate:
#
# * `count`: number of flights;
# * `avg_speed`: average speed in miles per hour.
#
# Keep only destinations with **more than 20 flights** and sort them by `avg_speed` from fastest to slowest.
#
# Display the 10 fastest destinations.
#
# Try to write this as a single method chain.

# %%
average_speed_by_destination = (
    flights
    .assign(
        speed = flights['distance'] / (flights['air_time'] / 60)
    )
    .groupby('dest')
    .agg(
        n_flights=('flight', 'size'),
        avg_speed=('speed', 'mean')
    )
    .query("n_flights > 20")
    .reset_index()
    .sort_values('avg_speed', ascending=False)
    .head(10)
)

average_speed_by_destination
# Out:
#    dest  n_flights   avg_speed
# 11  BQN        547  486.941156
# 83  SJU       3521  485.500289
# 37  HNL        428  483.518542
# 69  PSE        229  481.060702
# 89  STT        289  478.681312
# 45  LAX       9687  452.985962
# 85  SMF        164  451.506080
# 76  SAN       1647  451.474604
# 46  LGB        390  449.623567
# 81  SFO       8027  448.619269

# %% [markdown]
# ## Check the result
#
# A transformation is not finished just because the code ran.
#
# Before using the result, ask:
#
# * Does one row now represent what I think it represents?
# * Are the number of groups plausible?
# * Are the summary values plausible?
# * Did missing values affect the calculation?
# * Did filtering happen before or after aggregation as intended?
#
# A few simple checks can prevent incorrect conclusions.

# %%
average_speed_by_destination['avg_speed'].describe()
# Out:
# count     10.000000
# mean     466.991148
# std       17.205337
# min      448.619269
# 25%      451.482473
# 50%      465.833637
# 75%      482.904082
# max      486.941156
# Name: avg_speed, dtype: float64

# %% [markdown]
# ## All Done!
#
# In this session we used pandas transformations to answer analytical questions.
#
# We practised:
#
# * filtering observations with `query()`;
# * sorting observations with `sort_values()`;
# * selecting variables with `loc[]`;
# * renaming variables;
# * creating new variables with `assign()`;
# * grouping observations with `groupby()`;
# * calculating summaries with `agg()`;
# * combining several operations using method chaining;
# * checking that transformed results still make analytical sense.
#
# The key idea is:
#
# > **Start with the question, then decide what data transformation is required.**
#
# We will now move on to the structure of datasets and the principles of **tidy data**.
